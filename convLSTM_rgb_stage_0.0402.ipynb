# %%
import pandas as pd
import numpy as np
from convlstm import ConvLSTM
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
import os
from skimage import io
from sklearn.model_selection import train_test_split

# %%
data_train = pd.read_csv("dataset/data_skill_corner/label_edit.txt",skiprows=1,
                         names=['frame','intention_type','current_velocity','steering_wheel_angle','dlm'],
                         sep='\s+')
data_train = data_train.to_numpy()


#print (y_train.shape,y_test.shape)        
root_dir = 'dataset/data_skill_corner/rgb_0/'

# %%
class RGBDataset():
    """Face Landmarks dataset."""
        
    def __init__(self, nb_frames,root_dir):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.data = pd.read_csv("dataset/data_skill_corner/label_edit.txt",skiprows=1,
                                       names=['frame','intention_type','current_velocity',
                                              'steering_wheel_angle','dlm'],sep='\s+').to_numpy()
        self.data_train,_ = train_test_split(self.data,test_size = 0.3, shuffle=False)
        self.nb_frames = nb_frames
        self.root_dir = root_dir


    def __len__(self):
        return len(self.data_train) - self.nb_frames
        #return 200
    def __getitem__(self, idx):
        
        if torch.is_tensor(idx):
            idx = idx.tolist()
        
        X_train_t = [io.imread(os.path.join(self.root_dir,str(self.data_train[idx+i,0])+'.jpg')).astype(np.float32) for i in range (self.nb_frames)] 
        X_train = np.stack(X_train_t, axis=0)        
        X_train1 = np.moveaxis(X_train,-1,1)
        
        y_train = self.data_train[idx+self.nb_frames,2:4].astype(np.float32)
        y_train1 = y_train.reshape(1,2)
        sample = {'X_train': X_train1, 'y_train': y_train1}

        return sample

# %%
class RGBDataset_test():
    """Face Landmarks dataset."""
        
    def __init__(self, nb_frames,root_dir):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.data = pd.read_csv("dataset/data_skill_corner/label_edit.txt",skiprows=1,
                                       names=['frame','intention_type','current_velocity',
                                              'steering_wheel_angle','dlm'],sep='\s+').to_numpy()
        self.data_train,self.data_test= train_test_split(self.data,test_size = 0.3, shuffle=False)
        self.nb_frames = nb_frames
        self.root_dir = root_dir


    def __len__(self):
        return len(self.data_test) - self.nb_frames
        #return 200
    def __getitem__(self, idx):
        
        if torch.is_tensor(idx):
            idx = idx.tolist()
        
        X_test_t = [io.imread(os.path.join(self.root_dir,str(self.data_test[idx+i,0])+'.jpg')).astype(np.float32) for i in range (self.nb_frames)] 
        X_test = np.stack(X_test_t, axis=0)        
        X_test1 = np.moveaxis(X_test,-1,1)
        
        y_test = self.data_test[idx+self.nb_frames,2:4].astype(np.float32)
        y_test1 = y_test.reshape(1,2)
        sample = {'X_test': X_test1, 'y_test': y_test1}

        return sample

# %%
NUM_FRAMES=5

rgb_train = RGBDataset(NUM_FRAMES,'dataset/data_skill_corner/rgb_0/') #frame
rgb_test = RGBDataset_test(NUM_FRAMES,'dataset/data_skill_corner/rgb_0/')
sample = rgb_test[0]
#print (sample['X_test'].shape) #(5, 3, 224, 224)
#print (sample['y_test'].shape) #(1, 2)
from torch.utils.data import Dataset, DataLoader
dataloader_train = DataLoader(rgb_train, batch_size=8,
                        shuffle=False, num_workers=4)
dataloader_test = DataLoader(rgb_test, batch_size=8,
                        shuffle=False, num_workers=4)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        global NUM_FRAMES
        #self.conv1 = ConvLSTM(input_channels=1, hidden_channels=[64, 32, 32], kernel_size=3, step=5,
        #           effective_step=[4]).cuda()
        
        self.maxpool= nn.MaxPool3d((1,5,5),stride=(1,3,3))
        self.BD = nn.BatchNorm2d(16)
        self.drop = nn.Dropout(p=0.3)
        self.conv1 = ConvLSTM(input_size = (74,74), input_dim = 3, hidden_dim = [64, 32, 16], 
                              kernel_size = (3,3), num_layers = 3, batch_first=True)
        self.conv2 = nn.Conv2d(16, 16, kernel_size=3,stride=2)
        self.fc1 = nn.Linear(NUM_FRAMES*16*9*9, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 2)

    def forward(self, x):
        
        x = self.maxpool(x)
        #print (x.shape)
        x = self.conv1(x)     
        x = self.BD(x[0][0])    
        x = F.relu(F.max_pool2d(x,2))  
        #x = self.drop(x)
        x = self.BD(self.conv2(x))  
        x = F.relu(F.max_pool2d(x,2))  
        
        x = x.view(1,-1)
        #x = self.drop(x)
        x = F.relu(self.fc1(x))    
        
        
        x = F.relu(self.fc2(x))
        x = self.fc3(x).reshape(-1,1,2)
        return x


net = Net().cuda()

print(net)

print(sum(p.numel() for p in net.parameters()))
# Out:
# Net(
#   (maxpool): MaxPool3d(kernel_size=(1, 5, 5), stride=(1, 3, 3), padding=0, dilation=1, ceil_mode=False)
#   (BD): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (drop): Dropout(p=0.3, inplace=False)
#   (conv1): ConvLSTM(
#     (cell_list): ModuleList(
#       (0): ConvLSTMCell(
#         (conv): Conv2d(67, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (1): ConvLSTMCell(
#         (conv): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (2): ConvLSTMCell(
#         (conv): Conv2d(48, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (conv2): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2))
#   (fc1): Linear(in_features=6480, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=2, bias=True)
# )
# 1083462

# %%
import matplotlib.pyplot as plt
import torch.optim as optim
from torch.autograd import Variable
net1 = Net().cuda()
p = Variable(torch.randn(1,5, 3, 224, 224)).cuda()
q = Variable(torch.randn(1,1,2)).cuda()
#print (out.shape)

criterion = nn.MSELoss()
optimizer = optim.SGD(net1.parameters(), lr=0.01)
#optimizer = optim.Adam(net.parameters(), lr=0.01,betas=(0.9,0.99))
loss_values = []
for i in range (50):
    optimizer.zero_grad()
     
    out = net1(p)
    print(out.shape)

    los = criterion(out, q)
      
    los.backward()
    #print(i,los)
    optimizer.step()
    
    loss_values.append(los.item())
#del p,q,out,los
#torch.cuda.empty_cache()     
plt.plot(loss_values)     
print(loss_values[-1])
# Out:
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# torch.Size([1, 1, 2])
# 0.0

# %%
import torch.optim as optim
import matplotlib.pyplot as plt
# create your optimizer
net = Net().cuda()
criterion = nn.MSELoss()
#optimizer = optim.Adam(net.parameters(), lr=0.005,betas=(0.9,0.99))
optimizer = optim.SGD(net.parameters(), lr=0.0005)
loss_values = []
test_values = []
for epoch in range(200):  # loop over the dataset multiple times
    
    running_loss = 0.0
    running_test_loss = 0.0
    for i,data in enumerate(dataloader_train,0):
        
        # get the inputs; data is a list of [inputs, labels]
        X_t, y_t = data['X_train'].cuda(),data['y_train'].cuda()
        
        #print(X_t) #torch.Size([10, 5, 3, 224, 224]) torch.Size([10, 1, 2])
        # zero the parameter gradients
        optimizer.zero_grad()
        
        
        for j in range (len(X_t)):
            outputs = net(X_t[j].reshape(1,NUM_FRAMES,3,224,224))
            if j == 0:
                loss = criterion(outputs, y_t[j].reshape(1,1,2))
                #print(loss)
                
            else:
                loss += criterion(outputs, y_t[j].reshape(1,1,2))

        loss.backward()
        optimizer.step()       

        # print statistics
        
        running_loss += loss.item()
    loss_values.append(running_loss)
                   
    with torch.no_grad():        
        for i,data in enumerate(dataloader_test,0):
            X_test, y_test = data['X_test'].cuda(),data['y_test'].cuda()
            for j in range (len(X_test)):
                out_test = net(X_test[j].reshape(1,NUM_FRAMES,3,224,224))
                if j ==0:
                    test_loss = criterion(out_test, y_test[j].reshape(1,1,2))
                else:
                    test_loss += criterion(out_test, y_test[j].reshape(1,1,2))
                    
            running_test_loss += test_loss.item()

        test_values.append(running_test_loss)
       
    
    print('[epoch%d] running_loss: %.3f, test_loss:%.3f' %(epoch + 1, running_loss, running_test_loss))

          

    #plt.plot(loss_values) 
    #plt.plot(test_values) 
   
    


print('Finished Training')
# Out:
# [epoch1] running_loss: 245.519, test_loss:179.690
# [epoch2] running_loss: 186.620, test_loss:86.327
# [epoch3] running_loss: 133.353, test_loss:83.140
# [epoch4] running_loss: 104.641, test_loss:66.569
# [epoch5] running_loss: 86.385, test_loss:61.474
# [epoch6] running_loss: 75.619, test_loss:55.242
# [epoch7] running_loss: 67.776, test_loss:51.632
# [epoch8] running_loss: 63.619, test_loss:52.124
# [epoch9] running_loss: 60.357, test_loss:48.479
# [epoch10] running_loss: 56.363, test_loss:46.947
# [epoch11] running_loss: 53.614, test_loss:46.239
# [epoch12] running_loss: 51.249, test_loss:45.761
# [epoch13] running_loss: 49.426, test_loss:44.616
# [epoch14] running_loss: 47.111, test_loss:44.185
# [epoch15] running_loss: 46.105, test_loss:43.343
# [epoch16] running_loss: 44.262, test_loss:42.815
# [epoch17] running_loss: 42.920, test_loss:41.997
# [epoch18] running_loss: 41.427, test_loss:41.746
# [epoch19] running_loss: 41.020, test_loss:41.672
# [epoch20] running_loss: 39.918, test_loss:41.461
# [epoch21] running_loss: 38.775, test_loss:40.836
# [epoch22] running_loss: 37.463, test_loss:40.510
# [epoch23] running_loss: 36.441, test_loss:40.089
# [epoch24] running_loss: 35.537, test_loss:39.881
# [epoch25] running_loss: 34.707, test_loss:39.764
# [epoch26] running_loss: 33.780, test_loss:39.640
# [epoch27] running_loss: 32.912, test_loss:39.340
# [epoch28] running_loss: 32.258, test_loss:39.264
# [epoch29] running_loss: 31.374, test_loss:39.354
# [epoch30] running_loss: 31.000, test_loss:38.811
# [epoch31] running_loss: 30.651, test_loss:39.447
# [epoch32] running_loss: 29.502, test_loss:39.542
# [epoch33] running_loss: 28.779, test_loss:39.394
# [epoch34] running_loss: 28.211, test_loss:39.208
# [epoch35] running_loss: 27.595, test_loss:39.281
# [epoch36] running_loss: 27.074, test_loss:39.099
# [epoch37] running_loss: 26.539, test_loss:38.887
# [epoch38] running_loss: 25.916, test_loss:39.012
# [epoch39] running_loss: 25.420, test_loss:39.082
# [epoch40] running_loss: 24.915, test_loss:38.830
# [epoch41] running_loss: 24.543, test_loss:38.804
# [epoch42] running_loss: 24.035, test_loss:38.978
# [epoch43] running_loss: 23.611, test_loss:38.726
# [epoch44] running_loss: 23.156, test_loss:38.773
# [epoch45] running_loss: 22.850, test_loss:38.684
# [epoch46] running_loss: 22.360, test_loss:38.759
# [epoch47] running_loss: 22.003, test_loss:38.791
# [epoch48] running_loss: 21.662, test_loss:38.791
# [epoch49] running_loss: 21.391, test_loss:38.623
# [epoch50] running_loss: 20.945, test_loss:38.650
# [epoch51] running_loss: 20.607, test_loss:38.632
# [epoch52] running_loss: 20.286, test_loss:38.517
# [epoch53] running_loss: 20.007, test_loss:38.564
# [epoch54] running_loss: 19.649, test_loss:38.530
# [epoch55] running_loss: 19.351, test_loss:38.530
# [epoch56] running_loss: 19.053, test_loss:38.513
# [epoch57] running_loss: 18.762, test_loss:38.484
# [epoch58] running_loss: 18.534, test_loss:38.630
# [epoch59] running_loss: 18.225, test_loss:38.562
# [epoch60] running_loss: 17.956, test_loss:38.622
# [epoch61] running_loss: 17.772, test_loss:38.474
# [epoch62] running_loss: 17.475, test_loss:38.627
# [epoch63] running_loss: 17.314, test_loss:38.640
# [epoch64] running_loss: 16.972, test_loss:38.782
# [epoch65] running_loss: 16.780, test_loss:38.684
# [epoch66] running_loss: 16.599, test_loss:38.606
# [epoch67] running_loss: 16.487, test_loss:38.795
# [epoch68] running_loss: 16.105, test_loss:38.828
# [epoch69] running_loss: 16.021, test_loss:38.812
# [epoch70] running_loss: 15.765, test_loss:38.755
# [epoch71] running_loss: 15.590, test_loss:38.894
# [epoch72] running_loss: 15.341, test_loss:38.734
# [epoch73] running_loss: 15.248, test_loss:38.969
# [epoch74] running_loss: 14.942, test_loss:38.919
# [epoch75] running_loss: 14.809, test_loss:39.003
# [epoch76] running_loss: 14.639, test_loss:38.992
# [epoch77] running_loss: 14.530, test_loss:38.827
# [epoch78] running_loss: 14.352, test_loss:38.987
# [epoch79] running_loss: 14.090, test_loss:38.987
# [epoch80] running_loss: 13.921, test_loss:38.968
# [epoch81] running_loss: 13.760, test_loss:38.969
# [epoch82] running_loss: 13.728, test_loss:39.154
# [epoch83] running_loss: 13.517, test_loss:39.032
# [epoch84] running_loss: 13.237, test_loss:39.233
# [epoch85] running_loss: 13.109, test_loss:39.305
# [epoch86] running_loss: 12.971, test_loss:39.242
# [epoch87] running_loss: 12.851, test_loss:39.338
# [epoch88] running_loss: 12.799, test_loss:39.244
# [epoch89] running_loss: 12.695, test_loss:39.273
# [epoch90] running_loss: 12.453, test_loss:39.274
# [epoch91] running_loss: 12.269, test_loss:39.254
# [epoch92] running_loss: 12.203, test_loss:39.138
# [epoch93] running_loss: 12.089, test_loss:39.350
# [epoch94] running_loss: 12.024, test_loss:39.271
# [epoch95] running_loss: 11.983, test_loss:39.465
# [epoch96] running_loss: 11.664, test_loss:39.336
# [epoch97] running_loss: 11.581, test_loss:39.425
# [epoch98] running_loss: 11.443, test_loss:39.209
# [epoch99] running_loss: 11.464, test_loss:39.408
# [epoch100] running_loss: 11.281, test_loss:39.397
# [epoch101] running_loss: 11.174, test_loss:39.306
# [epoch102] running_loss: 11.110, test_loss:39.576
# [epoch103] running_loss: 10.897, test_loss:39.365
# [epoch104] running_loss: 10.935, test_loss:39.570
# [epoch105] running_loss: 10.685, test_loss:39.433
# [epoch106] running_loss: 10.735, test_loss:39.543
# [epoch107] running_loss: 10.504, test_loss:39.448
# [epoch108] running_loss: 10.362, test_loss:39.602
# [epoch109] running_loss: 10.318, test_loss:39.585
# [epoch110] running_loss: 10.255, test_loss:39.670
# [epoch111] running_loss: 10.139, test_loss:39.591
# [epoch112] running_loss: 10.059, test_loss:39.836
# [epoch113] running_loss: 9.949, test_loss:39.656
# [epoch114] running_loss: 9.962, test_loss:39.832
# [epoch115] running_loss: 9.793, test_loss:39.883
# [epoch116] running_loss: 9.694, test_loss:39.766
# [epoch117] running_loss: 9.645, test_loss:39.898
# [epoch118] running_loss: 9.625, test_loss:39.736
# [epoch119] running_loss: 9.482, test_loss:39.827
# [epoch120] running_loss: 9.245, test_loss:39.884
# [epoch121] running_loss: 9.318, test_loss:39.779
# [epoch122] running_loss: 9.091, test_loss:39.900
# [epoch123] running_loss: 9.161, test_loss:39.891
# [epoch124] running_loss: 9.212, test_loss:39.742
# [epoch125] running_loss: 8.997, test_loss:39.913
# [epoch126] running_loss: 8.947, test_loss:39.947
# [epoch127] running_loss: 8.836, test_loss:39.966
# [epoch128] running_loss: 8.775, test_loss:39.792
# [epoch129] running_loss: 8.734, test_loss:39.965
# [epoch130] running_loss: 8.567, test_loss:39.917
# [epoch131] running_loss: 8.751, test_loss:40.098
# [epoch132] running_loss: 8.465, test_loss:40.007
# [epoch133] running_loss: 8.405, test_loss:40.098
# [epoch134] running_loss: 8.425, test_loss:40.166
# [epoch135] running_loss: 8.375, test_loss:40.120
# [epoch136] running_loss: 8.387, test_loss:40.042
# [epoch137] running_loss: 8.265, test_loss:40.309
# [epoch138] running_loss: 8.156, test_loss:40.124
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/allenbi/anaconda3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/home/allenbi/anaconda3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/allenbi/anaconda3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/allenbi/anaconda3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/home/allenbi/anaconda3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/allenbi/anaconda3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/allenbi/anaconda3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
#   File "/home/allenbi/anaconda3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# Traceback (most recent call last):
#   File "/home/allenbi/anaconda3/lib/python3.7/multiprocessing/queues.py", line 242, in _feed
#     send_bytes(obj)
#   File "/home/allenbi/anaconda3/lib/python3.7/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/allenbi/anaconda3/lib/python3.7/multiprocessing/connection.py", line 404, in _send_bytes
#     self._send(header + buf)
#   File "/home/allenbi/anaconda3/lib/python3.7/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
# BrokenPipeError: [Errno 32] Broken pipe
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-a5d8894da757> in <module>
#      31                 loss += criterion(outputs, y_t[j].reshape(1,1,2))
#      32
# ---> 33         loss.backward()
#      34         optimizer.step()
#      35
#
# ~/anaconda3/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     193                 products. Defaults to ``False``.
#     194         """
# --> 195         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     196
#     197     def register_hook(self, hook):
#
# ~/anaconda3/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
plt.plot(loss_values) 
plt.plot(test_values)

# %%
torch.save(net.state_dict(), 'dataset/data_skill_corner/model_00402')

# %%
model = Net()
model.load_state_dict(torch.load('dataset/data_skill_corner/model_00402'))
model.eval()
# Out:
# <All keys matched successfully>
